# %%
# %store -r signal_1_1_hor
import util
import numpy as np
spec = util.getSpectro(signal_1_1_hor)

# %%
import matplotlib.pyplot as plt
import scipy.signal as sig
f, t, Sxx = sig.spectrogram(signal_1_1_hor, 25600)

plt.pcolormesh(t,f,10 * np.log10(Sxx))
plt.colorbar()
plt.show()

# %%
print(np.shape(t))
print(np.shape(f))
print(np.shape(Sxx))
# Out:
# (32034,)
# (129,)
# (129, 32034)

# %%
plt.specgram(signal_1_1_hor, Fs=25600)
plt.colorbar()
plt.show()

# %%
# %store -r signal_2_1_hor
plt.specgram(signal_2_1_hor, Fs=25600)
plt.show()
